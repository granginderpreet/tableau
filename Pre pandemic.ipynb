# %%
import pandas as pd
# The path to our CSV file
#pre pandemic 
file = "201904-citibike-tripdata.csv"

# Read our Kickstarter data into pandas
df0 = pd.read_csv(file)
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
prePandemic_df=df0

file = "201905-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)

file = "201906-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)

file = "201907-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)

file = "201908-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)

file = "201909-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)

file = "201910-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)

file = "201911-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)

file = "201912-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)

file = "202001-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)

file = "202002-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)

file = "202003-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'tripduration': 'tripDuration', 'starttime': 'startTime', 'stoptime':'stopTime', 'start station name':'startStation','end station name':'endStation', 
'start station latitude':'startLat','end station latitude':'endLat','start station longitude':'startLong','end station longitude':'endLong','usertype':'userType', 'birth year':'birthYear'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
prePandemic_df=pd.concat([prePandemic_df, df0], axis=False)
prePandemic_df.dtypes

prePandemic_by_10_df=prePandemic_df.dropna()



new_data = { "Subscriber":"member",
             "Customer":"casual"}
prePandemic_by_10_df["userType"] = prePandemic_by_10_df["userType"].map(new_data)

prePandemic_by_10_df.head()
df0.clear()
prePandemic_df.clear()
# Out:
# C:\Users\igrang\AppData\Local\Temp\ipykernel_17864\1806411289.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prePandemic_by_10_df["userType"] = prePandemic_by_10_df["userType"].map(new_data)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\igrang\DATACLASS\Tableau\Resources\Pre pandemic.ipynb Cell 1' in <module>
#     <a href='vscode-notebook-cell:/c%3A/Users/igrang/DATACLASS/Tableau/Resources/Pre%20pandemic.ipynb#ch0000000?line=128'>129</a> prePandemic_by_10_df["userType"] = prePandemic_by_10_df["userType"].map(new_data)
# ...

# %%
len(prePandemic_df)

# %%
del df0
del prePandemic_df
prePandemic_by_10_df.to_csv('city_bikes_pre_pandemic.csv', index=False         )
