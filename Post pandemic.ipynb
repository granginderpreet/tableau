# %%
import pandas as pd
# The path to our CSV file

# %%
#Most recent year (transitioning out of  pandemic) 
file = "202104-citibike-tripdata.csv"

# Read our Kickstarter data into pandas
df0 = pd.read_csv(file)
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)

latest_df=df0

file = "202105-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)

file = "202106-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)

file = "202107-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0.head()
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)

file = "202108-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)

file = "202109-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)

file = "202110-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)

file = "202111-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)

file = "202112-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)

file = "202201-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)

file = "202202-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)

file = "202203-citibike-tripdata.csv"
df0 = pd.read_csv(file)
df0.columns
df0 = df0.rename(columns={'rideable_type': 'bikeType', 'started_at': 'startTime', 'ended_at':'stopTime', 'start_station_name':'startStation','end_station_name':'endStation', 
'start_lat':'startLat','end_lat':'endLat','start_lng':'startLong','end_lng':'endLong','member_casual':'userType'})
df0 = df0.filter(['tripDuration','startTime','stopTime', 'startStation','endStation','startLat','endLat','startLong','endLong','userType','gender','birthYear'], axis=1)
df0=df0.sample(frac=0.1)
latest_df=pd.concat([latest_df, df0], axis=False)
len(latest_df)




#Calculate the trip duration in minutes
latest_df.startTime = pd.to_datetime(latest_df.startTime)
latest_df.stopTime = pd.to_datetime(latest_df.stopTime)
latest_df["tripDuration"] = (latest_df.stopTime - latest_df.startTime)
latest_df['tripDuration'] = latest_df['tripDuration'].dt.total_seconds().div(60).astype(int)
latest_df.head()

column_names = ["tripDuration", "startTime", "stopTime","startStation","endStation","startLat","endLat", "startLong","endLong","userType"]

latest_df = latest_df.reindex(columns=column_names)
latest_df.head()
latest_by_10_df=latest_df.dropna()
df0.clear()
latest_df.clear()

latest_by_10_df.to_csv('city_bikes_latest.csv', index=False         )  
len(latest_df)
# Out:
# C:\Users\igrang\AppData\Local\Temp\ipykernel_32196\2771563292.py:5: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv(file)
# C:\Users\igrang\AppData\Local\Temp\ipykernel_32196\2771563292.py:14: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv(file)
# C:\Users\igrang\AppData\Local\Temp\ipykernel_32196\2771563292.py:22: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv(file)
# C:\Users\igrang\AppData\Local\Temp\ipykernel_32196\2771563292.py:32: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv(file)
# C:\Users\igrang\AppData\Local\Temp\ipykernel_32196\2771563292.py:42: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv(file)
# ...

# %%
del df0
del latest_df
